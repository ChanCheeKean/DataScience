# %%
# !apt install subversion
# !mkdir data
# !svn checkout https://github.com/ChanCheeKean/datasets/trunk/nlp data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle, re, itertools, random
import nltk, spacy
from keras.preprocessing import sequence, text
from keras.models import Sequential, Model
from keras.layers.embeddings import Embedding
from keras.layers import Input, Activation, Dense, Permute, Dropout, LSTM, add, dot, concatenate

# %% [markdown]
# Material:
#
# Jason Weston, Antoine Bordes, Sumit Chopra, Tomas Mikolov, Alexander M. Rush, "Towards AI-Complete Question Answering: A Set of Prerequisite Toy Tasks", http://arxiv.org/abs/1502.05698
#
# Sainbayar Sukhbaatar, Arthur Szlam, Jason Weston, Rob Fergus, "End-To-End Memory Networks", http://arxiv.org/abs/1503.08895

# %% [markdown]
# # 1) Pre-Processing

# %%
def vectorizer(data):
    # split into stories, questions and answer
    story = [[word.lower() for word in sent[0]] for sent in data]
    question = [[word.lower() for word in sent[1]] for sent in data]
    answers = [sent[2].lower() for sent in data]
    
    # tokenized the text
    story_seq = tokenizer.texts_to_sequences(story)
    questions_seq = tokenizer.texts_to_sequences(question)

    # padding
    inputs = sequence.pad_sequences(story_seq, maxlen=max_story_len)
    queries = sequence.pad_sequences(questions_seq, maxlen=max_question_len)
    output = np.array([0 if x =='no' else 1 for x in answers])
    
    return inputs, queries, output

# %%
with open("./data/train_qa.txt", "rb") as fp:
    train_data =  pickle.load(fp)

with open("./data/test_qa.txt", "rb") as fp:
    test_data =  pickle.load(fp)

# see the shape
all_data = np.vstack([test_data, train_data])
all_data.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# (11000, 3)

# %%
stories = [x[0] for x in all_data]
questions = [x[1] for x in all_data]
answers = [x[2] for x in all_data]

print(' '.join(stories[0]))
print(' '.join(questions[0]))
print(''.join(answers[0]))
# Out:
# Mary got the milk there . John moved to the bedroom .
# Is John in the kitchen ?
# no

# %%
# tokenized the text
tokenizer = text.Tokenizer(filters=[])
tokenizer.fit_on_texts(stories + questions)

# add an extra space to hold a 0 for Keras's pad_sequences
max_story_len = max([len(x) for x in stories])
max_question_len = max([len(x) for x in questions])

# %%
# train data, split into stories, questions and answers
trained_inputs, trained_queries, trained_output = vectorizer(train_data)
test_inputs, test_queries, test_output = vectorizer(train_data)

# %% [markdown]
# # 2) Model Architecture

# %%
class Transformer(Model):
    def __init__(self, vocab_size, nb_classes=2, dropout_rate=0.1, training=False):
        super(Transformer, self).__init__(name="transformer")
        
        # embed the inputs into a sequence of vectors
        self.input_encoder_m = Sequential()
        self.input_encoder_m.add(Embedding(input_dim=vocab_size, output_dim=64)) 
        self.input_encoder_m.add(Dropout(dropout_rate))
        
        # embed the inputs into a sequence of vectors of size query_maxlen
        self.input_encoder_c = Sequential()
        self.input_encoder_c.add(Embedding(input_dim=vocab_size, output_dim=max_question_len))
        self.input_encoder_c.add(Dropout(dropout_rate))
        
        # embed the questions into a sequence of vectors
        self.question_encoder = Sequential()
        self.question_encoder.add(Embedding(input_dim=vocab_size, output_dim=64, input_length=max_question_len))
        self.question_encoder.add(Dropout(dropout_rate))
        
        self.activation = Activation('softmax')
        self.permute = Permute((2, 1))
        self.lstm = LSTM(32)
        self.dropout = Dropout(dropout_rate)
        self.dense = Dense(nb_classes)
        
    def call(self, inputs, training):
        # encode input sequence and questions (which are indices) to sequences of dense vectors
        input_encoded_m = self.input_encoder_m(inputs[0])
        input_encoded_c = self.input_encoder_c(inputs[0])
        question_encoded = self.question_encoder(inputs[1])
        
        match = dot([input_encoded_m, question_encoded], axes=(2, 2))
        match = self.activation(match)
        
        # add the match matrix with the second input vector sequence
        response = add([match, input_encoded_c])
        response = self.permute(response)
        
        # Reduce with RNN (LSTM)
        answer = concatenate([response, question_encoded])
        answer = self.lstm(answer)

        # Regularization with Dropout
        answer = self.dropout(answer)
        answer = self.dense(answer)

        # we output a probability distribution over the vocabulary
        answer = self.activation(answer)
        return answer

V = len(tokenizer.word_index) + 1
NB_CLASSES = len(np.unique(trained_output))
DROPOUT_RATE = 0.3

transformer_model = Transformer(vocab_size=V, nb_classes=NB_CLASSES, dropout_rate=DROPOUT_RATE)
transformer_model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = transformer_model.fit([trained_inputs, trained_queries], trained_output, batch_size=32, epochs=50,
                                validation_data=([test_inputs, test_queries], test_output))
# Out:
# Epoch 1/50
# 313/313 [==============================] - 9s 20ms/step - loss: 0.6997 - accuracy: 0.4964 - val_loss: 0.6934 - val_accuracy: 0.4988
# Epoch 2/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6938 - accuracy: 0.5083 - val_loss: 0.6930 - val_accuracy: 0.5137
# Epoch 3/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6934 - accuracy: 0.5007 - val_loss: 0.6929 - val_accuracy: 0.5155
# Epoch 4/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6934 - accuracy: 0.4940 - val_loss: 0.6944 - val_accuracy: 0.5012
# Epoch 5/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6940 - accuracy: 0.4940 - val_loss: 0.6928 - val_accuracy: 0.5032
# Epoch 6/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6927 - accuracy: 0.5119 - val_loss: 0.6919 - val_accuracy: 0.5213
# Epoch 7/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6920 - accuracy: 0.5225 - val_loss: 0.6885 - val_accuracy: 0.5280
# Epoch 8/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6889 - accuracy: 0.5277 - val_loss: 0.6647 - val_accuracy: 0.5888
# Epoch 9/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6620 - accuracy: 0.5924 - val_loss: 0.6276 - val_accuracy: 0.6646
# Epoch 10/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6298 - accuracy: 0.6538 - val_loss: 0.5994 - val_accuracy: 0.6912
# Epoch 11/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6083 - accuracy: 0.6713 - val_loss: 0.5562 - val_accuracy: 0.7270
# Epoch 12/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.5642 - accuracy: 0.7069 - val_loss: 0.4955 - val_accuracy: 0.7762
# Epoch 13/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.5235 - accuracy: 0.7470 - val_loss: 0.4391 - val_accuracy: 0.8130
# Epoch 14/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4869 - accuracy: 0.7725 - val_loss: 0.4106 - val_accuracy: 0.8198
# Epoch 15/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4708 - accuracy: 0.7920 - val_loss: 0.4020 - val_accuracy: 0.8283
# Epoch 16/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4331 - accuracy: 0.8016 - val_loss: 0.3813 - val_accuracy: 0.8283
# Epoch 17/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4087 - accuracy: 0.8177 - val_loss: 0.3702 - val_accuracy: 0.8303
# Epoch 18/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4116 - accuracy: 0.8093 - val_loss: 0.3596 - val_accuracy: 0.8379
# Epoch 19/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3859 - accuracy: 0.8226 - val_loss: 0.3513 - val_accuracy: 0.8386
# Epoch 20/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.3858 - accuracy: 0.8202 - val_loss: 0.3444 - val_accuracy: 0.8474
# Epoch 21/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3668 - accuracy: 0.8343 - val_loss: 0.3217 - val_accuracy: 0.8569
# Epoch 22/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3622 - accuracy: 0.8383 - val_loss: 0.3152 - val_accuracy: 0.8591
# Epoch 23/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3529 - accuracy: 0.8454 - val_loss: 0.3120 - val_accuracy: 0.8638
# Epoch 24/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3438 - accuracy: 0.8452 - val_loss: 0.3056 - val_accuracy: 0.8691
# Epoch 25/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3347 - accuracy: 0.8542 - val_loss: 0.2973 - val_accuracy: 0.8761
# Epoch 26/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3313 - accuracy: 0.8554 - val_loss: 0.2943 - val_accuracy: 0.8749
# Epoch 27/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.3417 - accuracy: 0.8516 - val_loss: 0.2817 - val_accuracy: 0.8779
# Epoch 28/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3319 - accuracy: 0.8555 - val_loss: 0.2799 - val_accuracy: 0.8781
# Epoch 29/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3178 - accuracy: 0.8610 - val_loss: 0.2769 - val_accuracy: 0.8788
# Epoch 30/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3115 - accuracy: 0.8669 - val_loss: 0.2791 - val_accuracy: 0.8791
# Epoch 31/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3230 - accuracy: 0.8584 - val_loss: 0.2700 - val_accuracy: 0.8830
# Epoch 32/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.3195 - accuracy: 0.8575 - val_loss: 0.2699 - val_accuracy: 0.8833
# Epoch 33/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3081 - accuracy: 0.8685 - val_loss: 0.2710 - val_accuracy: 0.8828
# Epoch 34/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3131 - accuracy: 0.8607 - val_loss: 0.2979 - val_accuracy: 0.8683
# Epoch 35/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.3051 - accuracy: 0.8652 - val_loss: 0.2704 - val_accuracy: 0.8825
# Epoch 36/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2992 - accuracy: 0.8668 - val_loss: 0.2578 - val_accuracy: 0.8864
# Epoch 37/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2987 - accuracy: 0.8699 - val_loss: 0.2556 - val_accuracy: 0.8902
# Epoch 38/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2894 - accuracy: 0.8705 - val_loss: 0.2654 - val_accuracy: 0.8849
# Epoch 39/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2995 - accuracy: 0.8704 - val_loss: 0.2541 - val_accuracy: 0.8887
# Epoch 40/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2927 - accuracy: 0.8678 - val_loss: 0.2545 - val_accuracy: 0.8894
# Epoch 41/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2915 - accuracy: 0.8753 - val_loss: 0.2513 - val_accuracy: 0.8903
# Epoch 42/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2914 - accuracy: 0.8728 - val_loss: 0.2520 - val_accuracy: 0.8911
# Epoch 43/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2941 - accuracy: 0.8750 - val_loss: 0.2419 - val_accuracy: 0.8939
# Epoch 44/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2936 - accuracy: 0.8688 - val_loss: 0.2506 - val_accuracy: 0.8889
# Epoch 45/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2836 - accuracy: 0.8735 - val_loss: 0.2384 - val_accuracy: 0.8964
# Epoch 46/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2753 - accuracy: 0.8791 - val_loss: 0.2471 - val_accuracy: 0.8944
# Epoch 47/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2916 - accuracy: 0.8750 - val_loss: 0.2383 - val_accuracy: 0.8945
# Epoch 48/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2802 - accuracy: 0.8769 - val_loss: 0.2336 - val_accuracy: 0.8972
# Epoch 49/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2717 - accuracy: 0.8772 - val_loss: 0.2305 - val_accuracy: 0.8992
# Epoch 50/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.2721 - accuracy: 0.8853 - val_loss: 0.2263 - val_accuracy: 0.9013

# %%
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
test_inputs.shape
# Out:
# (10000, 156)

# %%
rand = random.randint(0, len(test_inputs))
story = ' '.join(tokenizer.index_word.get(word) for word in test_inputs[rand] if word != 0)
print(story)
query = ' '.join(tokenizer.index_word.get(word) for word in test_queries[rand] if word != 0)
print(query)
print(f"True Answer: {test_output[rand]} \n")

pred_results = transformer_model.predict(([test_inputs, test_queries]))
result = pred_results[rand].argmax()
print(f"Predicted Answer is {result}!")
print("Probability of certainty was: ", pred_results[rand].max())
# Out:
# sandra got the milk there . john went to the garden . sandra travelled to the hallway . sandra discarded the milk .
# is sandra in the bathroom ?
# True Answer: 0
#
# Predicted Answer is 0!
# Probability of certainty was:  0.99998844

# %%
# create own queries
my_story = "John left the kitchen . Sandra dropped the football in the garden ."
my_question = "Is Sandra in the garden?"
mydata = [(my_story.split(), my_question.split(), 'yes')]
my_story, my_ques, my_ans = vectorizer(mydata)
pred_result = transformer_model.predict(([my_story, my_ques])).argmax()
print(f"Predicted Answer is {pred_result}!")
# Out:
# Predicted Answer is 1!
