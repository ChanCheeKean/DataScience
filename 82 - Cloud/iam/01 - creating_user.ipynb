# %%
import boto3

# %%
iam_client = boto3.client('iam')
ce_client = boto3.client('ce')
session = boto3.Session()
credentials = session.get_credentials()

# %%
# print all suer access key
response = iam_client.list_users()
for user in response['Users']:
    user_name = user['UserName']
    response = iam_client.list_access_keys(UserName=user_name)
    access_keys = response['AccessKeyMetadata']
    if access_keys:
        for key in access_keys:
            if key['Status'] == 'Active':
                print(f"IAM User: {user_name}")
                print(f"Access Key ID: {key['AccessKeyId']}")
                # print(f"Secret Access Key: {key['SecretAccessKey']}")
                print("-----------------------")
# Out:
# IAM User: aeb-change-log-user
# Access Key ID: AKIA4M4CYEL37YQWEL4M
# -----------------------
# IAM User: aeb-newsroom-putOnly
# Access Key ID: AKIA4M4CYEL3QFIJOHFB
# -----------------------
# IAM User: airbyte-test-user
# Access Key ID: AKIA4M4CYEL3YXANS4UZ
# -----------------------
# IAM User: airflow-earned-optimizer-s3
# Access Key ID: AKIA4M4CYEL3R6T7KANQ
# -----------------------
# IAM User: airflow-earned-optimizer-s3
# Access Key ID: AKIA4M4CYEL3QU4XKKGZ
# -----------------------
# IAM User: airflow_svc_user
# Access Key ID: AKIA4M4CYEL3V6GQWFEA
# -----------------------
# IAM User: amit_keys
# Access Key ID: AKIA4M4CYEL34KVDI3HG
# -----------------------
# IAM User: astronomer
# Access Key ID: AKIA4M4CYEL3ZUA2UWWG
# -----------------------
# IAM User: astronomer_deployment
# Access Key ID: AKIA4M4CYEL355IY7JVJ
# -----------------------
# IAM User: astronomer_deployment
# Access Key ID: AKIA4M4CYEL32GTS54SX
# -----------------------
# IAM User: bias-detection-tool
# Access Key ID: AKIA4M4CYEL376SDW34T
# -----------------------
# IAM User: data-sync
# Access Key ID: AKIA4M4CYEL3VNTBYZ7Y
# -----------------------
# IAM User: databricks-connect
# Access Key ID: AKIA4M4CYEL355GRTLOD
# -----------------------
# IAM User: disinformation-user
# Access Key ID: AKIA4M4CYEL36WOE35YE
# -----------------------
# IAM User: dsml-dev
# Access Key ID: AKIA4M4CYEL346LMCKVY
# -----------------------
# IAM User: dsml-dev
# Access Key ID: AKIA4M4CYEL3Q2IMR2EK
# -----------------------
# IAM User: dxi-bpo-etm-read
# Access Key ID: AKIA4M4CYEL3QHTUNA4J
# -----------------------
# IAM User: dxi-bpo-read-stream
# Access Key ID: AKIA4M4CYEL3VMWVR6KW
# -----------------------
# IAM User: dxi-bpo-resourcing-read-write
# Access Key ID: AKIA4M4CYEL3TKBOHBEY
# -----------------------
# IAM User: dxi-lexis-nexis-preprocessed-read
# Access Key ID: AKIA4M4CYEL337QD4BHA
# -----------------------
# IAM User: dxi-serverless-user
# Access Key ID: AKIA4M4CYEL3RBROA66J
# -----------------------
# IAM User: emo-serverless-backend
# Access Key ID: AKIA4M4CYEL32LYEMJVJ
# -----------------------
# IAM User: emo-serverless-backend
# Access Key ID: AKIA4M4CYEL3SSXZDELL
# -----------------------
# IAM User: github-actions
# Access Key ID: AKIA4M4CYEL36QRX4UMV
# -----------------------
# IAM User: github-actions-react-apps
# Access Key ID: AKIA4M4CYEL3TASJ45ID
# -----------------------
# IAM User: hugo
# Access Key ID: AKIA4M4CYEL3ZPDGD2DA
# -----------------------
# IAM User: joye-key
# Access Key ID: AKIA4M4CYEL32XWUJTUP
# -----------------------
# IAM User: joye-key
# Access Key ID: AKIA4M4CYEL36MK277PD
# -----------------------
# IAM User: kean_access
# Access Key ID: AKIA4M4CYEL3RJPPKUUK
# -----------------------
# IAM User: leo-keys
# Access Key ID: AKIA4M4CYEL34O5LR2EH
# -----------------------
# IAM User: leo-keys
# Access Key ID: AKIA4M4CYEL3R3LMFA5R
# -----------------------
# IAM User: local-admin
# Access Key ID: AKIA4M4CYEL3ZUXT6UPK
# -----------------------
# IAM User: mwaa-truststream-user
# Access Key ID: AKIA4M4CYEL36RGU4NNH
# -----------------------
# IAM User: mwaa-truststream-user
# Access Key ID: AKIA4M4CYEL36JGFLSYF
# -----------------------
# IAM User: peter-keys
# Access Key ID: AKIA4M4CYEL327VUR74U
# -----------------------
# IAM User: PeterChazotte
# Access Key ID: AKIA4M4CYEL37FEEAFVV
# -----------------------
# IAM User: Product-team
# Access Key ID: AKIA4M4CYEL35KEQOO7X
# -----------------------
# IAM User: Product-team
# Access Key ID: AKIA4M4CYEL3TOIFOVPG
# -----------------------
# IAM User: prometheus
# Access Key ID: AKIA4M4CYEL3S3XFGVMQ
# -----------------------
# IAM User: quantiphi
# Access Key ID: AKIA4M4CYEL3552GN3UP
# -----------------------
# IAM User: r-connector
# Access Key ID: AKIA4M4CYEL33LVAFI7T
# -----------------------
# IAM User: regis-user
# Access Key ID: AKIA4M4CYEL3ZPAUTCGY
# -----------------------
# IAM User: sagemaker
# Access Key ID: AKIA4M4CYEL3VDLNTX4U
# -----------------------
# IAM User: sagemaker
# Access Key ID: AKIA4M4CYEL377DLATQH
# -----------------------
# IAM User: sas-server-s3-z-drive-access
# Access Key ID: AKIA4M4CYEL333MMJBSF
# -----------------------
# IAM User: sas-server-s3-z-drive-access
# Access Key ID: AKIA4M4CYEL3TCK6GS4O
# -----------------------
# IAM User: secadmin
# Access Key ID: AKIA4M4CYEL3QTV4TPPH
# -----------------------
# IAM User: secrets-manager-read
# Access Key ID: AKIA4M4CYEL35DRAJHVH
# -----------------------
# IAM User: secrets-manager-read
# Access Key ID: AKIA4M4CYEL35CETQGZ3
# -----------------------
# IAM User: ses-smtp-user.20201125-104446
# Access Key ID: AKIA4M4CYEL3W7XRZ3S2
# -----------------------
# IAM User: ses-smtp-user.20211209-182707
# Access Key ID: AKIA4M4CYEL34734HENK
# -----------------------
# IAM User: suyee-keys
# Access Key ID: AKIA4M4CYEL3QQRZK7K7
# -----------------------
# IAM User: talkwalker-user
# Access Key ID: AKIA4M4CYEL3RTJYZRYY
# -----------------------
# IAM User: tencent-risk-sensing
# Access Key ID: AKIA4M4CYEL3YILEJVBD
# -----------------------
# IAM User: tencent-risk-sensing
# Access Key ID: AKIA4M4CYEL3YNH66MAG
# -----------------------
# IAM User: testuser2
# Access Key ID: AKIA4M4CYEL34N6XZFJN
# -----------------------
# IAM User: trust-stream-pipeline
# Access Key ID: AKIA4M4CYEL32TNNS7U7
# -----------------------
# IAM User: trust-stream-pipeline
# Access Key ID: AKIA4M4CYEL337IL6P6N
# -----------------------
# IAM User: vpcadmin
# Access Key ID: AKIA4M4CYEL3UOUYJK7A
# -----------------------
# IAM User: yml_test
# Access Key ID: AKIA4M4CYEL3ZME7RBH6
# -----------------------
# IAM User: yml_test
# Access Key ID: AKIA4M4CYEL3VVZKLKPY
# -----------------------
# IAM User: yohanes-key
# Access Key ID: AKIA4M4CYEL3ZTYQPKRR
# -----------------------
# IAM User: yuki-tencent-risk-sensing
# Access Key ID: AKIA4M4CYEL33JEHXBWW
# -----------------------
# IAM User: yuqi-keys
# Access Key ID: AKIA4M4CYEL3SJZZAP4U
# -----------------------
# IAM User: yuqi-keys
# Access Key ID: AKIA4M4CYEL35OBIAMYV
# -----------------------
