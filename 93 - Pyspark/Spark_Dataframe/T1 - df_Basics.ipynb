# %% [markdown]
# # Spark DataFrame Basics
#
# Spark DataFrames are the workhouse and main way of working with Spark and Python post Spark 2.0. DataFrames act as powerful versions of tables, with rows and columns, easily handling large datasets. The shift to DataFrames provides many advantages:
# * A much simpler syntax
# * Ability to use SQL directly in the dataframe
# * Operations are automatically distributed across RDDs
#
# If you've used R or even the pandas library with Python you are probably already familiar with the concept of DataFrames. Spark DataFrame expand on a lot of these concepts, allowing you to transfer that knowledge easily by understanding the simple syntax of Spark DataFrames. Remember that the main advantage to using Spark DataFrames vs those other programs is that Spark can handle data across many RDDs, huge data sets that would never fit on a single computer. That comes at a slight cost of some "peculiar" syntax choices, but after this course you will feel very comfortable with all those topics!
#
# Let's get started!
#
# ## Creating a DataFrame
#
# First we need to start a SparkSession:

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd /content/gdrive/MyDrive/Colab Notebooks/93 - Pyspark/Spark_Dataframe
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Colab Notebooks/93 - Pyspark/Spark_Dataframe

# %%
# !pip install pyspark
# !pip install deltalake
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.1.2)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9)
# Requirement already satisfied: deltalake in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: pyarrow>=4 in /usr/local/lib/python3.7/dist-packages (from deltalake) (4.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow>=4->deltalake) (1.19.5)

# %%
from pyspark.sql import SparkSession

# %%
from deltalake import DeltaTable

def fetch_delta_data(path):
    # Read the Delta Table using the Rust API
    dt = DeltaTable(path)

    df = dt.to_pyarrow_table().to_pandas()
    return df

# %%
path = 's3://dxi-risksensing-data/test_data/dash_inputs/risk_levels_by_country'
df_risk_country = fetch_delta_data(path)
# Out:
# ---------------------------------------------------------------------------
# PyDeltaTableError                         Traceback (most recent call last)
# <ipython-input-57-04c19fd705b1> in <module>()
#       1 path = 's3://dxi-risksensing-data/test_data/dash_inputs/risk_levels_by_country'
# ----> 2 df_risk_country = fetch_delta_data(path)
#
# <ipython-input-55-d1aa13affbd0> in fetch_delta_data(path)
#       3 def fetch_delta_data(path):
#       4     # Read the Delta Table using the Rust API
# ----> 5     dt = DeltaTable(path)
#       6
#       7     df = dt.to_pyarrow_table().to_pandas()
#
# /usr/local/lib/python3.7/dist-packages/deltalake/table.py in __init__(self, table_uri, version)
#      71         :param version: version of the DeltaTable
#      72         """
# ---> 73         self._table = RawDeltaTable(table_uri, version=version)
#      74         self._metadata = Metadata(self._table)
#      75
#
# PyDeltaTableError: Failed to load checkpoint: Failed to read checkpoint content: Failed to read S3 object content: Couldn't find AWS credentials in environment, credentials file, or IAM role.

# %% [markdown]
# Then start the SparkSession

# %%
# May take a little while on a local computer
spark = SparkSession.builder.appName("Basics").getOrCreate()

# %% [markdown]
# You will first need to get the data from a file (or connect to a large distributed file like HDFS, we'll talk about this later once we move to larger datasets on AWS EC2).

# %%
# We'll discuss how to read other options later.
# This dataset is from Spark's examples

# Might be a little slow locally
df = spark.read.json('data/people.json')

# %% [markdown]
# #### Showing the data

# %%
# Note how data is missing!
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# ['age', 'name']

# %%
df.describe()
# Out:
# DataFrame[summary: string, age: string, name: string]

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   null|
# | stddev|7.7781745930520225|   null|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %% [markdown]
# Some data types make it easier to infer schema (like tabular formats such as csv which we will show later).
#
# However you often have to set the schema yourself if you aren't dealing with a .read method that doesn't have inferSchema() built-in.
#
# Spark has all the tools you need for this, it just requires a very specific structure:

# %%
from pyspark.sql.types import StructField,StringType,IntegerType,StructType

# %% [markdown]
# Next we need to create the list of Structure fields
#     * :param name: string, name of the field.
#     * :param dataType: :class:`DataType` of the field.
#     * :param nullable: boolean, whether the field can be null (None) or not.

# %%
data_schema = [StructField("age", IntegerType(), True),StructField("name", StringType(), True)]

# %%
final_struc = StructType(fields=data_schema)

# %%
df = spark.read.json('./data/people.json', schema=final_struc)

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %% [markdown]
# This steps are only needed for json files

# %% [markdown]
# ### Grabbing the data

# %%
df['age']
# Out:
# Column<b'age'>

# %%
# this is column object
type(df['age'])
# Out:
# pyspark.sql.column.Column

# %%
# use select method to see the results
df.select('age')
# Out:
# DataFrame[age: int]

# %%
df.select('age').show()
# Out:
# +----+
# | age|
# +----+
# |null|
# |  30|
# |  19|
# +----+

# %%
# different from df['age'], it returns dataframe of a column
type(df.select('age'))
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# Returns list of Row objects
df.head(2)
# Out:
# [Row(age=None, name='Michael'), Row(age=30, name='Andy')]

# %%
# there is row object in pyspark df
type(df.head(2)[0])
# Out:
# pyspark.sql.types.Row

# %% [markdown]
# Multiple Columns:

# %%
df.select(['age','name'])
# Out:
# DataFrame[age: int, name: string]

# %%
df.select(['age','name']).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %% [markdown]
# ### Creating new columns

# %%
# Adding a new column with a simple copy of age
df.withColumn('doubleage',df['age']*2).show()
# Out:
# +----+-------+---------+
# | age|   name|doubleage|
# +----+-------+---------+
# |null|Michael|     null|
# |  30|   Andy|       60|
# |  19| Justin|       38|
# +----+-------+---------+

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
# Simple Rename
df.withColumnRenamed('age','supernewage').show()
# Out:
# +-----------+-------+
# |supernewage|   name|
# +-----------+-------+
# |       null|Michael|
# |         30|   Andy|
# |         19| Justin|
# +-----------+-------+

# %% [markdown]
# More complicated operations to create new columns

# %%
df.withColumn('add_one_age',df['age']+1).show()
# Out:
# +----+-------+-----------+
# | age|   name|add_one_age|
# +----+-------+-----------+
# |null|Michael|       null|
# |  30|   Andy|         31|
# |  19| Justin|         20|
# +----+-------+-----------+

# %% [markdown]
# ### Using SQL
#
# To use SQL queries directly with the dataframe, you will need to register it to a temporary view:

# %%
# Register the DataFrame as a SQL temporary view
df.createOrReplaceTempView("people")

# %%
sql_results = spark.sql("SELECT * FROM people")

# %%
sql_results
# Out:
# DataFrame[age: int, name: string]

# %%
sql_results.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
spark.sql("SELECT * FROM people WHERE age=30").show()
# Out:
# +---+----+
# |age|name|
# +---+----+
# | 30|Andy|
# +---+----+

# %% [markdown]
# We won't really be focusing on using the SQL syntax for this course in general, but keep in mind it is always there for you to get you out of bind quickly with your SQL skills!

# %% [markdown]
# Alright that is all we need to know for now!
