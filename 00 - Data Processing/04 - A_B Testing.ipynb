# %% [markdown]
# # Statistical A/B Testing
#
# <img src="https://miro.medium.com/max/828/1*Vzkwzrs4DOmBBa1LymW-PQ.webp">
#
# 1. [A/B Testing: A Complete Guide to Statistical Testing](https://towardsdatascience.com/a-b-testing-a-complete-guide-to-statistical-testing-e3f1db140499) [Implementation](https://towardsdatascience.com/simple-and-complet-guide-to-a-b-testing-c34154d0ce5a)
#
# 2. [An intuitive explanation of Hypothesis Testing and P-Values](https://towardsdatascience.com/an-intuitive-explanation-of-hypothesis-testing-and-p-values-8391db2c90f)
#
# 3. [1-way ANOVA from scratch](https://towardsdatascience.com/1-way-anova-from-scratch-dissecting-the-anova-table-with-a-worked-example-170f4f2e58ad)
#
#     * Test whether sample differences can be generalized as population differences
#     * The null hypothesis states that the mean of all groups is equal
#     * The alternative hypothesis states that at least one of the means is different
#     * Use F statistic to compute the P-Value using the F distribution with df1 and df2 degrees of freedom
#     * If the p-value is below μ, we reject the null hypothesis, this means that at least one group mean is significantly different
#
# 4. [Unvariate Regression F-Test](https://www.statology.org/f-test-python/) | [Sklearn f_regression](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html#sklearn.feature_selection.f_regression)
#
# 5. [Comparison of F-test and mutual information](https://scikit-learn.org/stable/auto_examples/feature_selection/plot_f_test_vs_mi.html#sphx-glr-auto-examples-feature-selection-plot-f-test-vs-mi-py)
