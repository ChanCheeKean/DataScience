# %%
# !wget https://files.grouplens.org/datasets/movielens/ml-100k.zip
# !unzip ml-100k.zip

# %%
# !pip install scikit-surprise

# %% [markdown]
# # Data Loading

# %%
import random
import numpy as np
import pandas as pd
from typing import *
from IPython.display import display, HTML, Markdown
import warnings
from scipy.linalg import svd
warnings.filterwarnings('ignore')

# %%
ratings_data = pd.read_csv(
    'ml-100k/u.data', sep='\t', encoding="ISO-8859-1",
    names=['user_id', 'movie_id', 'rating', 'timestamp'])
ratings_data = ratings_data[['user_id', 'movie_id', 'rating']]
movie_data = pd.read_csv(
    'ml-100k/u.item', sep='|', encoding="ISO-8859-1",
    names= [
        'movie_id', 'title', 'release_date', 'video_release_date', 'url', 
        'unknown', 'Action', 'Adventure', 'Animation', "Children's",
        'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 
        'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
)
movie_data['release_date'] = pd.to_datetime(movie_data['release_date'])
ratings_data['user_id'] = ratings_data['user_id'].map(lambda k: f"User {k}")
ratings_and_movies = ratings_data.set_index('movie_id').join(movie_data['title']).reset_index(drop=True)
ratings_and_movies['movie_title'] = ratings_and_movies['title']
movielens_df = ratings_and_movies[['user_id', 'movie_title', 'rating']].sample(frac=1) 

# Remove movies with few ratings
movielens_df = movielens_df[movielens_df.groupby('movie_title')['user_id'].transform('count') > 50]
movielens_df.head()
# Out:
#         user_id                                  movie_title  rating
# 22188  User 543                   Weekend at Bernie's (1989)       3
# 85956  User 593       Candyman: Farewell to the Flesh (1995)       3
# 48887  User 758  3 Ninjas: High Noon At Mega Mountain (1998)       4
# 83097  User 683                       MatchMaker, The (1997)       3
# 10501   User 60                            Free Willy (1993)       4

# %% [markdown]
# # SVD Training with Surprise
#
# The famous SVD algorithm, as popularized by Simon Funk during the Netflix Prize
#
# <img src='https://miro.medium.com/max/700/1*qSmm211H6kbIb1y0eKwQlg.png'>
#
# Considering the figure above, notice how the rating matrix, R, has missing values in some places. The matrix factorization algorithm uses a procedure such as gradient descent to minimize the error when predicting existing ratings using the matrix factors. Thus, an algorithm like SVD builds a recommendation system by allowing us to “fill in the gaps” in the rating matrix, predicting the ratings that each user would assign to each item in the dataset.
#
# <img src='https://miro.medium.com/max/170/0*O4gMln9rCdtUVovH.png'>
#
# * Matrix U: singular matrix of (user*latent factors)
# * Matrix S: diagonal matrix (shows the strength of each latent factor)
# * Matrix V: singular matrix of (item*latent factors)

# %%
from surprise import SVD, NMF
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate, train_test_split
from scipy.spatial.distance import cosine

# %%
matrix_df = movielens_df.groupby(['user_id', 'movie_title'])['rating'].mean().unstack()
matrix_df.head()
# Out:
# movie_title  12 Angry Men (1957)  20,000 Leagues Under the Sea (1954)  \
# user_id
# User 1                       5.0                                  1.0
# User 10                      NaN                                  NaN
# User 100                     NaN                                  NaN
# User 101                     NaN                                  NaN
# User 102                     NaN                                  NaN
#
# movie_title  2001: A Space Odyssey (1968)  \
# user_id
# User 1                                4.0
# User 10                               5.0
# User 100                              NaN
# User 101                              NaN
# User 102                              NaN
#
# movie_title  3 Ninjas: High Noon At Mega Mountain (1998)  \
# user_id
# User 1                                               NaN
# User 10                                              NaN
# User 100                                             5.0
# User 101                                             NaN
# User 102                                             3.0
#
# movie_title  39 Steps, The (1935)  Absolute Power (1997)  Abyss, The (1989)  \
# user_id
# User 1                        NaN                    NaN                4.0
# User 10                       NaN                    NaN                NaN
# User 100                      NaN                    NaN                NaN
# User 101                      NaN                    NaN                NaN
# User 102                      NaN                    NaN                2.0
#
# movie_title  Ace Ventura: Pet Detective (1994)  Across the Sea of Time (1995)  \
# user_id
# User 1                                     4.0                            NaN
# User 10                                    NaN                            NaN
# User 100                                   NaN                            NaN
# User 101                                   NaN                            3.0
# User 102                                   3.0                            NaN
#
# movie_title  Addams Family Values (1993)  ...  Wings of Desire (1987)  \
# user_id                                   ...
# User 1                               NaN  ...                     NaN
# User 10                              4.0  ...                     4.0
# User 100                             NaN  ...                     NaN
# User 101                             NaN  ...                     NaN
# User 102                             3.0  ...                     3.0
#
# movie_title  Wings of the Dove, The (1997)  Winter Guest, The (1997)  \
# user_id
# User 1                                 NaN                       NaN
# User 10                                NaN                       NaN
# User 100                               3.0                       4.0
# User 101                               NaN                       NaN
# User 102                               NaN                       NaN
#
# movie_title  Wizard of Oz, The (1939)  Wolf (1994)  \
# user_id
# User 1                            1.0          NaN
# User 10                           NaN          NaN
# User 100                          NaN          NaN
# User 101                          NaN          NaN
# User 102                          NaN          2.0
#
# movie_title  Wrong Trousers, The (1993)  Wyatt Earp (1994)  \
# user_id
# User 1                              5.0                NaN
# User 10                             4.0                NaN
# User 100                            NaN                NaN
# User 101                            NaN                NaN
# User 102                            3.0                NaN
#
# movie_title  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# User 1                             5.0                1.0
# User 10                            NaN                NaN
# User 100                           NaN                NaN
# User 101                           NaN                NaN
# User 102                           NaN                2.0
#
# movie_title  Young Poisoner's Handbook, The (1995)
# user_id
# User 1                                         NaN
# User 10                                        NaN
# User 100                                       NaN
# User 101                                       4.0
# User 102                                       3.0
#
# [5 rows x 588 columns]

# %%
# A reader tells our SVD what the lower and upper bound of ratings
# the dataframe must have exact same order
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(movielens_df[['user_id', 'movie_title', 'rating']], reader)
trainset, testset = train_test_split(data, test_size=.25)

# define model
# model = NMF(n_factors=100)
model = SVD(n_factors=100)
model.fit(trainset)

print('Train Size: ', trainset.n_items)
print('Model Output Size Size: ', model.qi.shape)

# Normalization
print(pd.DataFrame(model.qi).iloc[0].pow(2).sum())
model.qi /= np.linalg.norm(model.qi, ord=2, axis=1).reshape(-1, 1)
print(pd.DataFrame(model.qi).iloc[0].pow(2).sum())
# Out:
# Train Size:  588
# Model Output Size Size:  (588, 100)
# 1.4846171029533204
# 0.9999999999999999

# %% [markdown]
# # Recommendations via Product
#
# 1.   Finding similarity between vectors
# 2.   Two products are "similar" when the cosine distance is close to 0

# %%
def get_vector_by_movie_title(movie_title: str, trained_model: SVD) -> np.array:
    """Returns the latent features of a movie in the form of a numpy array"""
    movie_row_idx = trained_model.trainset._raw2inner_id_items[movie_title]
    return trained_model.qi[movie_row_idx]

def cosine_distance(vector_a: np.array, vector_b: np.array) -> float:
    """Returns a float indicating the similarity between two vectors"""
    return cosine(vector_a, vector_b)

# fetch vector (100,) of each movie
toy_story_vec = get_vector_by_movie_title('Stargate (1994)', model)
wizard_of_oz_vec = get_vector_by_movie_title('Wizard of Oz, The (1939)', model)
similarity_score = cosine_distance(toy_story_vec, wizard_of_oz_vec)
similarity_score
# Out:
# 0.9703864331189428

# %%
# Predict a score between any combination of user and a product
a_user = "User 196"
a_product = "Toy Story (1995)"
model.predict(a_user, a_product)
# Out:
# Prediction(uid='User 196', iid='Toy Story (1995)', r_ui=None, est=3.7050975721744837, details={'was_impossible': False})

# %% [markdown]
# # SVD From Scratch

# %%
import numpy as np
import pandas as pd
from scipy.linalg import sqrtm
def create_utility_matrix(data):

    userList = data.iloc[:, 0].tolist()
    itemList = data.iloc[:, 1].tolist()
    valueList = data.iloc[:, 2].tolist()

    users = list(set(data.iloc[:, 0]))
    items = list(set(data.iloc[:, 1]))
    users_index = {users[i]: i for i in range(len(users))}
    X = data.groupby(['user_id', 'movie_title'])['rating'].mean().unstack()
    itemcols = list(X.columns)
    items_index = {itemcols[i]: i for i in range(len(itemcols))}
    # users_index gives us a mapping of user_id to index of user
    # items_index provides the same for items
    return X, users_index, items_index

matrix, users_index, items_index = create_utility_matrix(movielens_df[['user_id', 'movie_title', 'rating']])
print({k: users_index[k] for k in list(users_index)[:5]})
print({k: items_index[k] for k in list(items_index)[:5]})
matrix.head()
# Out:
# {'User 295': 0, 'User 382': 1, 'User 793': 2, 'User 730': 3, 'User 800': 4}
# {'12 Angry Men (1957)': 0, '20,000 Leagues Under the Sea (1954)': 1, '2001: A Space Odyssey (1968)': 2, '3 Ninjas: High Noon At Mega Mountain (1998)': 3, '39 Steps, The (1935)': 4}
# movie_title  12 Angry Men (1957)  20,000 Leagues Under the Sea (1954)  \
# user_id
# User 1                       5.0                                  1.0
# User 10                      NaN                                  NaN
# User 100                     NaN                                  NaN
# User 101                     NaN                                  NaN
# User 102                     NaN                                  NaN
#
# movie_title  2001: A Space Odyssey (1968)  \
# user_id
# User 1                                4.0
# User 10                               5.0
# User 100                              NaN
# User 101                              NaN
# User 102                              NaN
#
# movie_title  3 Ninjas: High Noon At Mega Mountain (1998)  \
# user_id
# User 1                                               NaN
# User 10                                              NaN
# User 100                                             5.0
# User 101                                             NaN
# User 102                                             3.0
#
# movie_title  39 Steps, The (1935)  Absolute Power (1997)  Abyss, The (1989)  \
# user_id
# User 1                        NaN                    NaN                4.0
# User 10                       NaN                    NaN                NaN
# User 100                      NaN                    NaN                NaN
# User 101                      NaN                    NaN                NaN
# User 102                      NaN                    NaN                2.0
#
# movie_title  Ace Ventura: Pet Detective (1994)  Across the Sea of Time (1995)  \
# user_id
# User 1                                     4.0                            NaN
# User 10                                    NaN                            NaN
# User 100                                   NaN                            NaN
# User 101                                   NaN                            3.0
# User 102                                   3.0                            NaN
#
# movie_title  Addams Family Values (1993)  ...  Wings of Desire (1987)  \
# user_id                                   ...
# User 1                               NaN  ...                     NaN
# User 10                              4.0  ...                     4.0
# User 100                             NaN  ...                     NaN
# User 101                             NaN  ...                     NaN
# User 102                             3.0  ...                     3.0
#
# movie_title  Wings of the Dove, The (1997)  Winter Guest, The (1997)  \
# user_id
# User 1                                 NaN                       NaN
# User 10                                NaN                       NaN
# User 100                               3.0                       4.0
# User 101                               NaN                       NaN
# User 102                               NaN                       NaN
#
# movie_title  Wizard of Oz, The (1939)  Wolf (1994)  \
# user_id
# User 1                            1.0          NaN
# User 10                           NaN          NaN
# User 100                          NaN          NaN
# User 101                          NaN          NaN
# User 102                          NaN          2.0
#
# movie_title  Wrong Trousers, The (1993)  Wyatt Earp (1994)  \
# user_id
# User 1                              5.0                NaN
# User 10                             4.0                NaN
# User 100                            NaN                NaN
# User 101                            NaN                NaN
# User 102                            3.0                NaN
#
# movie_title  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# User 1                             5.0                1.0
# User 10                            NaN                NaN
# User 100                           NaN                NaN
# User 101                           NaN                NaN
# User 102                           NaN                2.0
#
# movie_title  Young Poisoner's Handbook, The (1995)
# user_id
# User 1                                         NaN
# User 10                                        NaN
# User 100                                       NaN
# User 101                                       4.0
# User 102                                       3.0
#
# [5 rows x 588 columns]

# %%
# svd computation
def svd(train, k=10):

    # mask nan
    # (user_len, item_len)
    utilMat = np.array(train)
    mask = np.isnan(utilMat)
    masked_arr = np.ma.masked_array(utilMat, mask)

    # (item_len, )
    item_means = np.mean(masked_arr, axis=0)

    # nan entries will replaced by the average rating for each item
    utilMat = masked_arr.filled(item_means)

    # repeat n times
    # (user_len, item_len)
    x = np.tile(item_means, (utilMat.shape[0], 1))

    # remove the per item average from all entries.
    # nan entries will be essentially zero now
    utilMat = utilMat - x

    # U and V are user and item features
    # (user_len, item_len), (item_len, ), (item_len, item_len)
    U, s, V = np.linalg.svd(utilMat, full_matrices=False)
    # (item_len, item_len)
    s = np.diag(s)

    # we take only the k most significant features
    # (user_len, k), (k, k),  (k, item_len)
    U = U[:, 0:k]
    s = s[0:k, 0:k]
    V = V[0:k, :]
    s_root = sqrtm(s)

    # (user_len, k), (k, item_len),  (user_len, item_len)
    Usk = np.dot(U, s_root)
    skV = np.dot(s_root, V)
    UsV = np.dot(Usk, skV)

    # (user_len, item_len)
    UsV = UsV + x
    return UsV

svdout = svd(matrix, k=8)
svdout.shape
pd.DataFrame(svdout)
# Out:
#           0         1         2         3         4         5         6    \
# 0    4.199733  2.929045  4.468040  4.366316  3.858861  3.214125  3.611128
# 1    4.026639  3.266965  4.554342  4.245449  3.823679  3.185469  3.623345
# 2    3.903553  3.221726  4.276884  4.220665  3.745596  3.118609  3.555333
# 3    3.858623  3.213532  4.260816  4.231564  3.738413  3.089159  3.542118
# 4    3.561750  3.077233  4.198610  3.924273  3.635111  2.987294  3.292013
# ..        ...       ...       ...       ...       ...       ...       ...
# 938  3.649053  3.136354  4.156348  4.428685  3.779579  3.149519  3.548811
# 939  3.894031  3.203647  4.402085  4.257788  3.777984  3.155898  3.583413
# 940  3.975906  3.159790  4.319091  4.294317  3.781502  3.141206  3.587373
# 941  3.877963  3.236000  4.317508  4.217914  3.738214  3.111209  3.532754
# 942  3.918374  3.230206  4.359516  4.305906  3.755553  3.154220  3.621915
#
#           7         8         9    ...       578       579       580  \
# 0    3.270183  2.576072  3.614184  ...  4.604247  3.752501  3.126952
# 1    3.532759  2.889405  3.562327  ...  4.468479  3.577183  3.187155
# 2    3.546616  2.918380  3.580010  ...  4.264758  3.585284  3.201162
# 3    3.569792  2.876407  3.599563  ...  4.211298  3.592918  3.208329
# 4    3.265913  2.735502  2.669129  ...  4.104190  3.599319  3.228967
# ..        ...       ...       ...  ...       ...       ...       ...
# 938  3.783714  2.884154  3.612817  ...  4.144141  3.768066  3.288147
# 939  3.544050  2.873601  3.550735  ...  4.288641  3.603784  3.175904
# 940  3.544522  2.829524  3.714841  ...  4.316444  3.631978  3.154540
# 941  3.521595  2.920837  3.507734  ...  4.253917  3.599638  3.216939
# 942  3.559378  2.927204  3.759322  ...  4.188491  3.574931  3.161815
#
#           581       582       583       584       585       586       587
# 0    3.662570  3.311182  4.767485  2.669598  3.990083  2.529174  2.964891
# 1    3.917031  3.820195  4.326858  2.734663  3.851587  2.803854  3.159952
# 2    3.703869  3.646839  4.091474  2.694848  3.829535  2.666061  3.042608
# 3    3.731005  3.733454  3.947064  2.701265  3.806736  2.695573  3.062678
# 4    3.792095  3.001013  3.372608  2.319125  3.685881  2.282373  2.478176
# ..        ...       ...       ...       ...       ...       ...       ...
# 938  3.687041  3.696049  3.845026  2.595790  3.753150  2.649559  2.962217
# 939  3.765709  3.727341  4.140450  2.679524  3.753377  2.735549  3.154864
# 940  3.693199  3.759035  4.174863  2.713421  3.819180  2.709881  3.184018
# 941  3.772984  3.664391  4.000890  2.687154  3.815453  2.678871  3.087809
# 942  3.660501  3.826805  4.228229  2.784331  3.728826  2.816717  3.342474
#
# [943 rows x 588 columns]

# %%
# predictions
pred = []
for _,row in movielens_df.iterrows():
    user = row['user_id']
    item = row['movie_title']
    u_index = users_index[user]

    if item in items_index:
        i_index = items_index[item]
        pred_rating = svdout[u_index, i_index]
    else:
        pred_rating = np.mean(svdout[u_index, :])
    pred.append(pred_rating)

# evaluation
def rmse(true, pred):
    # this will be used towards the end
    x = true - pred
    return sum([xi*xi for xi in x])/len(x)

print(rmse(movielens_df['rating'], pred))
movielens_df['pred'] = pred
movielens_df
# Out:
# 1.012769630048917
#         user_id                                  movie_title  rating      pred
# 22188  User 543                   Weekend at Bernie's (1989)       3  3.692298
# 85956  User 593       Candyman: Farewell to the Flesh (1995)       3  3.275483
# 48887  User 758  3 Ninjas: High Noon At Mega Mountain (1998)       4  4.259777
# 83097  User 683                       MatchMaker, The (1997)       3  2.073555
# 10501   User 60                            Free Willy (1993)       4  3.245242
# ...         ...                                          ...     ...       ...
# 6240   User 373                                  I.Q. (1994)       5  4.059340
# 16628  User 555       Maya Lin: A Strong Clear Vision (1994)       4  3.304590
# 43651  User 224                        Secrets & Lies (1996)       3  3.163558
# 40096    User 1                               Air Bud (1997)       1  2.431016
# 58807  User 417          Transformers: The Movie, The (1986)       4  3.723052
#
# [83239 rows x 4 columns]
